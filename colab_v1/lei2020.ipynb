# %%
run build_model.py
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# first_layer (Dense)          (None, 256)               4352
# _________________________________________________________________
# drop_out_1 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer_1 (Dense)       (None, 512)               131584
# _________________________________________________________________
# drop_out_2 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden_layer_2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# drop_out_3 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer_3 (Dense)       (None, 128)               32896
# ...

# %%
from google.colab import files

files.download('build_model.py')
files.download('minMaxScaler.pkl')
files.download('model_mqrcs.h5')
files.download('neuralNetwork.png')
files.download('oneHotEncoder.pkl')
files.download('plot_acc.png')
files.download('plot_loss.png')
