# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
run build_model.py
# Out:
# ---------- Begin Cross Validation Nº1 ----------
# > Fit the model, please wait...
# Epoch 00090: early stopping
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9994
# accuracy: 99.94%
# > Saving model...
# --------------------------------------------------
#
#
# ---------- Begin Cross Validation Nº2 ----------
# > Fit the model, please wait...
# Epoch 00049: early stopping
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9971
# accuracy: 99.71%
# > Saving model...
# --------------------------------------------------
#
#
# ---------- Begin Cross Validation Nº3 ----------
# > Fit the model, please wait...
# Epoch 00070: early stopping
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9965
# accuracy: 99.65%
# > Saving model...
# --------------------------------------------------
#
#
# ---------- Begin Cross Validation Nº4 ----------
# > Fit the model, please wait...
# ...

# %%
# !zip -r plots.zip plots
# !zip -r models.zip models

# !cp plots.zip '/content/drive/My Drive/LEI-2020/'
# !cp models.zip '/content/drive/My Drive/LEI-2020/'
# Out:
#   adding: plots/ (stored 0%)
#   adding: plots/plot_loss_1.png (deflated 5%)
#   adding: plots/plot_acc_6.png (deflated 6%)
#   adding: plots/plot_acc_9.png (deflated 6%)
#   adding: plots/plot_acc_4.png (deflated 5%)
#   adding: plots/plot_acc_7.png (deflated 5%)
#   adding: plots/plot_loss_6.png (deflated 5%)
#   adding: plots/plot_loss_2.png (deflated 5%)
#   adding: plots/plot_loss_7.png (deflated 5%)
#   adding: plots/plot_acc_10.png (deflated 5%)
#   adding: plots/plot_acc_1.png (deflated 5%)
#   adding: plots/plot_acc_3.png (deflated 5%)
#   adding: plots/plot_loss_10.png (deflated 5%)
#   adding: plots/plot_loss_8.png (deflated 5%)
#   adding: plots/plot_acc_2.png (deflated 5%)
#   adding: plots/plot_acc_8.png (deflated 5%)
#   adding: plots/plot_loss_9.png (deflated 5%)
#   adding: plots/plot_loss_5.png (deflated 5%)
#   adding: plots/plot_acc_5.png (deflated 6%)
#   adding: plots/plot_loss_3.png (deflated 5%)
#   adding: plots/plot_loss_4.png (deflated 5%)
# ...

# %%
from google.colab import files

files.download('/content/build_model.py')
files.download('/content/minMaxScaler.pkl')
files.download('/content/neuralNetwork.png')
files.download('/content/oneHotEncoder.pkl')
files.download('/content/dataset_labelled.csv')
